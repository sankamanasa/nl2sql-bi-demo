# %% [markdown]
# # 🧠 LLM-Powered Business Intelligence Demo
#
# # Natural Language to SQL for Financial Analytics

# %%
import os
print(os.path.exists('../src/nl2sql.py'))  # Should print: True
# Out:
# True

# %%
from src.nl2sql import NL2SQLDemo

demo = NL2SQLDemo('data/stock_database.db')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.nl2sql import NL2SQLDemo
#       3 demo = NL2SQLDemo('data/stock_database.db')
#
# File c:\Users\sanka\Desktop\Projects\nl2sql-bi-demo\notebooks\..\src\__init__.py:1
# ----> 1 from .nl2sql import NL2SQLDemo
#       2 from .data_loader import fetch_stock_data, create_database
#
# File c:\Users\sanka\Desktop\Projects\nl2sql-bi-demo\notebooks\..\src\nl2sql.py:6
#       2 """
#       3 NL2SQL Demo - Natural Language to SQL for Financial Analytics
#       4 """
# ----> 6 import pandas as pd
#       7 import sqlite3
#       8 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Initialize the demo
demo = NL2SQLDemo('../data/stock_database.db')
print('✅ NL2SQL Demo initialized!')

# %% [markdown]
# ## Query 1: Average Stock Price

# %%
# Ask about average price
result = demo.ask("What is the average price of Apple stock?")

# %%
## Query 2: Moving Averages

# %%
# Moving averages
result = demo.ask("Show me the 7-day and 30-day moving averages for Apple")
